# %%
import pandas as pd
import os
import shutil
qc_dir = '/Users/brandonmcclung/Data/pickles/merlin_cc/post_QC/'
files = os.listdir(qc_dir)
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
dir = '/Users/brandonmcclung/Data/pickles/merlin_cc/ran_2nc/'
test_df = pd.read_pickle(dir+'qcd_2019_04_merlin_cc_df.p')
test_df

# for file in files:
#     print(file)
#     test_df = pd.read_pickle(qc_dir+file)
#     print(test_df)

# test_df
# Out:
#                                   Date              Time       Lat        Lon  \
# Date_Time
# 2019-04-01 04:19:44.188800  04/01/2019  04:19:44.1888000  29:16:08  -79:22:31
# 2019-04-01 04:46:49.229900  04/01/2019  04:46:49.2299000  29:02:40  -79:33:47
# 2019-04-01 04:46:49.230600  04/01/2019  04:46:49.2306000  29:02:04  -79:34:53
# 2019-04-01 04:46:49.230900  04/01/2019  04:46:49.2309000  29:10:15  -79:13:22
# 2019-04-01 04:46:49.231700  04/01/2019  04:46:49.2317000  29:02:18  -79:32:27
# ...                                ...               ...       ...        ...
# 2019-04-26 19:14:54.803200  04/26/2019  19:14:54.8032000  28:20:06  -80:15:24
# 2019-04-26 19:14:54.803300  04/26/2019  19:14:54.8033000  28:20:03  -80:15:12
# 2019-04-26 19:14:54.846300  04/26/2019  19:14:54.8463000  28:19:45  -80:15:32
# 2019-04-26 19:14:54.846400  04/26/2019  19:14:54.8464000  28:19:36  -80:16:55
# 2019-04-26 19:14:54.846500  04/26/2019  19:14:54.8465000  28:19:38  -80:16:34
#
# ...

# %%
df3 = pd.read_csv('/Users/brandonmcclung/Data/txt_dump/merlin_cc_src_subset.txt')
df3.set_index(['yr','mo'],inplace=True)
df3.sort_index(inplace=True)
df3.plot()
# Out:
# <Axes: xlabel='yr,mo'>

# %% [markdown]
# for file in files
